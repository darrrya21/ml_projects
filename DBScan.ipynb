# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
import zipfile
from sklearn.datasets import make_blobs
from sklearn.neighbors import NearestNeighbors

# %%
X, y = make_blobs(n_samples=500, centers=4, cluster_std=0.6, random_state=0)

# %%
plt.scatter(X[:, 0], X[:, 1], c=y)

# %%
knn = NearestNeighbors(n_neighbors=4)
knn.fit(X)
# Out:
# NearestNeighbors(n_neighbors=4)

# %%
distances, indices = knn.kneighbors(X)

# %%
distances_sort = np.sort(distances, axis=0)[:, 1]

# %%
plt.plot(distances_sort)
plt.ylim(0.2, 0.4)
# Out:
# (0.2, 0.4)

# %%
dbscan_model = DBSCAN(eps=0.5, min_samples=5)
dbscan_model.fit(X)
# Out:
# DBSCAN()

# %%
plt.scatter(X[:, 0], X[:, 1], c=dbscan_model.labels_)
